# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Intro to Pyhton

# %%
print("Programming for data science")
output='CSE'
output2="CSE- EWU"
print(output)
print(output2)
# Out:
# Programming for data science
# CSE
# CSE- EWU

# %%
num_1=6
num_2=5
sum= num_1+num_2
sub= num_1-num_2
prod= num_1*num_2
div= num_1/num_2
div_int= num_1//num_2
rem= num_1 % num_2
print("Result of sum=",sum)
print("Result of sub=",sub)
print("Result of prod=",prod)
print("Result of div=",div)
print("Result of div_int=",div_int)
print("Result of rem=",rem)
print()
print("Result of sum=",sum, "\nResult of sub=", sub, "\nResult of prod=",prod)
# Out:
# Result of sum= 11
# Result of sub= 1
# Result of prod= 30
# Result of div= 1.2
# Result of div_int= 1
# Result of rem= 1
#
# Result of sum= 11
# Result of sub= 1
# Result of prod= 30

# %%
NUM_1=float(input("Enter a number: "))
print(type(NUM_1))
print("Number:",NUM_1)
# Out:
# Enter a number: 6
# <class 'float'>
# Number: 6.0
