# %%
# !gdown --id 1g0Y27WxxsQCWWagNqUvajlre3tDOKsbM
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1g0Y27WxxsQCWWagNqUvajlre3tDOKsbM
# To: /content/syntactic_car_factory_data.csv
# 100% 528k/528k [00:00<00:00, 113MB/s]

# %%
import pandas as pd
df= pd.read_csv("/content/syntactic_car_factory_data.csv")
df
# Out:
#       Unnamed: 0   Sensor_1   Sensor_2   Sensor_3   Sensor_4   Sensor_5  \
# 0              0  54.967142  48.617357        NaN        NaN  47.658466
# 1              1  45.365823  45.342702  52.419623  30.867198  32.750822
# 2              2  64.656488  47.742237  50.675282  35.752518  44.556173
# 3              3  43.982934  68.522782  49.865028  39.422891        NaN
# 4              4  57.384666  51.713683  48.843517  46.988963  35.214780
# ...          ...        ...        ...        ...        ...        ...
# 2995        2995        NaN  45.423488  61.252898  31.607248  74.452990
# 2996        2996  60.291254  34.472952  57.015888  49.878215  55.770441
# 2997        2997  56.622722  54.275963  59.446989  64.060693  31.235822
# 2998        2998  33.460284  46.184133  40.518947        NaN  52.798413
# 2999        2999  47.814617  68.248892  58.767068  37.679915  37.387917
#
#        Sensor_6   Sensor_7   Sensor_8   Sensor_9  Sensor_10 Sensor_Status  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Sensor_1   Sensor_2   Sensor_3   Sensor_4   Sensor_5  \
# 0           0  54.967142  48.617357        NaN        NaN  47.658466
# 1           1  45.365823  45.342702  52.419623  30.867198  32.750822
# 2           2  64.656488  47.742237  50.675282  35.752518  44.556173
# 3           3  43.982934  68.522782  49.865028  39.422891        NaN
# 4           4  57.384666  51.713683  48.843517  46.988963  35.214780
#
#     Sensor_6   Sensor_7   Sensor_8   Sensor_9  Sensor_10 Sensor_Status  \
# 0  47.658630  65.792128  57.674347  45.305256        NaN           NaN
# 1  44.377125  39.871689  53.142473  40.919759        NaN        Faulty
# 2  51.109226  38.490064  53.756980  43.993613  47.083063        Faulty
# 3  37.791564  52.088636  30.403299        NaN  51.968612        Faulty
# 4  42.801558  45.393612        NaN  53.436183  32.369598           NaN
#
#      Shift    Line
# 0      NaN  Line B
# 1  Morning  Line A
# 2  Morning  Line C
# 3    Night  Line A
# 4    Night  Line A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3000 non-null   int64
#  1   Sensor_1       2471 non-null   float64
#  2   Sensor_2       2439 non-null   float64
#  3   Sensor_3       2460 non-null   float64
#  4   Sensor_4       2422 non-null   float64
#  5   Sensor_5       2439 non-null   float64
#  6   Sensor_6       2477 non-null   float64
#  7   Sensor_7       2467 non-null   float64
#  8   Sensor_8       2436 non-null   float64
#  9   Sensor_9       2415 non-null   float64
#  10  Sensor_10      2478 non-null   float64
#  11  Sensor_Status  2469 non-null   object
#  12  Shift          2451 non-null   object
#  13  Line           2470 non-null   object
# dtypes: float64(10), int64(1), object(3)
# memory usage: 328.2+ KB

# %%
df=df.drop(columns=["Unnamed: 0"],axis=1)

# %%
df.describe()
# Out:
#           Sensor_1     Sensor_2     Sensor_3     Sensor_4     Sensor_5  \
# count  2471.000000  2439.000000  2460.000000  2422.000000  2439.000000
# mean     50.073990    50.061812    49.734218    49.759796    49.889483
# std      10.258144     9.951859     9.967660     9.846068    10.226766
# min      10.775997    13.116347    13.647998    18.007354    11.436247
# 25%      43.088655    43.379361    42.753646    43.163223    42.983580
# 50%      50.074318    49.955182    49.621977    50.115479    49.944040
# 75%      57.269417    56.673198    56.520956    56.226342    56.891770
# max      86.113501    89.423310    81.404229    94.790843    82.877612
#
#           Sensor_6     Sensor_7     Sensor_8     Sensor_9    Sensor_10
# count  2477.000000  2467.000000  2436.000000  2415.000000  2478.000000
# mean     49.913762    50.251579    49.944761    49.824527    50.055791
# std      10.111651    10.091090     9.893117    10.146338     9.670296
# ...

# %%
df["Sensor_1"].mean()
# Out:
# 50.073989977145295

# %%
df[["Sensor_1","Sensor_2"]].mean()
# Out:
# Sensor_1    50.073990
# Sensor_2    50.061812
# dtype: float64

# %%
data=df[:10]
data
# Out:
#     Sensor_1   Sensor_2   Sensor_3   Sensor_4   Sensor_5   Sensor_6  \
# 0  54.967142  48.617357        NaN        NaN  47.658466  47.658630
# 1  45.365823  45.342702  52.419623  30.867198  32.750822  44.377125
# 2  64.656488  47.742237  50.675282  35.752518  44.556173  51.109226
# 3  43.982934  68.522782  49.865028  39.422891        NaN  37.791564
# 4  57.384666  51.713683  48.843517  46.988963  35.214780  42.801558
# 5  53.240840  46.149177  43.230780        NaN        NaN  59.312801
# 6        NaN  48.143410  38.936650        NaN  58.125258  63.562400
# 7  53.613956  65.380366  49.641740  65.646437  23.802549  58.219025
# 8  47.803281  53.571126  64.778940        NaN  41.915064  44.982430
# 9  50.970775        NaN  42.979469  46.723379  46.078918  35.364851
#
#     Sensor_7   Sensor_8   Sensor_9  Sensor_10 Sensor_Status    Shift    Line
# 0  65.792128  57.674347  45.305256        NaN           NaN      NaN  Line B
# ...

# %%
df.isna().sum()
# Out:
# Sensor_1         529
# Sensor_2         561
# Sensor_3         540
# Sensor_4         578
# Sensor_5         561
# Sensor_6         523
# Sensor_7         533
# Sensor_8         564
# Sensor_9         585
# Sensor_10        522
# Sensor_Status    531
# Shift            549
# Line             530
# dtype: int64

# %%
df["Sensor_10"]=df["Sensor_10"].fillna(df["Sensor_10"].mean())
df.head()
# Out:
#     Sensor_1   Sensor_2   Sensor_3   Sensor_4   Sensor_5   Sensor_6  \
# 0  54.967142  48.617357        NaN        NaN  47.658466  47.658630
# 1  45.365823  45.342702  52.419623  30.867198  32.750822  44.377125
# 2  64.656488  47.742237  50.675282  35.752518  44.556173  51.109226
# 3  43.982934  68.522782  49.865028  39.422891        NaN  37.791564
# 4  57.384666  51.713683  48.843517  46.988963  35.214780  42.801558
#
#     Sensor_7   Sensor_8   Sensor_9  Sensor_10 Sensor_Status    Shift    Line
# 0  65.792128  57.674347  45.305256  50.055791           NaN      NaN  Line B
# 1  39.871689  53.142473  40.919759  50.055791        Faulty  Morning  Line A
# 2  38.490064  53.756980  43.993613  47.083063        Faulty  Morning  Line C
# 3  52.088636  30.403299        NaN  51.968612        Faulty    Night  Line A
# 4  45.393612        NaN  53.436183  32.369598           NaN    Night  Line A

# %%
df_number=df[["Sensor_1","Sensor_2","Sensor_3","Sensor_4","Sensor_5"]]
df_number=df_number.fillna(df_number.mean())
df_number.isna().sum()
# Out:
# Sensor_1    0
# Sensor_2    0
# Sensor_3    0
# Sensor_4    0
# Sensor_5    0
# dtype: int64

# %%
df["Sensor_Status"]=df["Sensor_Status"].fillna(df["Sensor_Status"].mode()[0])
df.isna().sum()
# Out:
# Unnamed: 0         0
# Sensor_1         529
# Sensor_2         561
# Sensor_3         540
# Sensor_4         578
# Sensor_5         561
# Sensor_6         523
# Sensor_7         533
# Sensor_8         564
# Sensor_9         585
# Sensor_10        522
# Sensor_Status      0
# Shift            549
# Line             530
# dtype: int64

# %%
df["Shift"]=df["Shift"].fillna(df["Shift"].mode())
df.isna().sum()
# Out:
# Unnamed: 0         0
# Sensor_1         529
# Sensor_2         561
# Sensor_3         540
# Sensor_4         578
# Sensor_5         561
# Sensor_6         523
# Sensor_7         533
# Sensor_8         564
# Sensor_9         585
# Sensor_10        522
# Sensor_Status      0
# Shift            548
# Line             530
# dtype: int64

# %%
df["Line"]=df["Line"].fillna(df["Line"].mode())
df.isna().sum()
# Out:
# Unnamed: 0         0
# Sensor_1         529
# Sensor_2         561
# Sensor_3         540
# Sensor_4         578
# Sensor_5         561
# Sensor_6         523
# Sensor_7         533
# Sensor_8         564
# Sensor_9         585
# Sensor_10        522
# Sensor_Status      0
# Shift            548
# Line             530
# dtype: int64

# %%
df=df[["Sensor_1","Sensor_2","Sensor_3","Sensor_4","Sensor_5", "Sensor_6","Sensor_7","Sensor_8","Sensor_9","Sensor_10"]]
df=df.fillna(df.mean())
df.isna().sum()
# Out:
# Sensor_1     0
# Sensor_2     0
# Sensor_3     0
# Sensor_4     0
# Sensor_5     0
# Sensor_6     0
# Sensor_7     0
# Sensor_8     0
# Sensor_9     0
# Sensor_10    0
# dtype: int64

# %%
df[["Sensor_1","Sensor_5","Sensor_10"]].hist()
# Out:
# array([[<Axes: title={'center': 'Sensor_1'}>,
#         <Axes: title={'center': 'Sensor_5'}>],
#        [<Axes: title={'center': 'Sensor_10'}>, <Axes: >]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot(x='Sensor_1',y='Sensor_4',kind='scatter')
# Out:
# <Axes: xlabel='Sensor_1', ylabel='Sensor_4'>

# %%
df['Sensor_Status'].value_counts()
# Out:
# Sensor_Status
# Operational    1383
# Maintenance     813
# Faulty          804
# Name: count, dtype: int64

# %%
df['Sensor_Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sensor_Status'>
